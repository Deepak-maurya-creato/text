# %%
! pip install pytesseract

# %%
! pip install opencv-python

# %%
! pip install matplotlib

# %%
import cv2

# %%
import pytesseract

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
tese_path = "C:/Program Files/Tesseract-OCR/tesseract.exe"

# %%
pytesseract.pytesseract.tesseract_cmd = tese_path

# %%
imgs = cv2.imread('test.jpg')

# %%
plt.imshow(imgs)

# %%
img2char = pytesseract.image_to_string(imgs)

# %%
print(img2char)
# Out:
# Behind every girl's
# favorite song is an
# untold story.

# %%
img2box = pytesseract.image_to_boxes(imgs)

# %%
print(img2box)
# Out:
# B 54 203 80 235 0
# e 83 202 103 225 0
# h 98 202 117 237 0
# i 104 203 130 236 0
# n 132 203 144 237 0
# d 145 203 195 236 0
# e 209 193 218 225 0
# v 209 202 229 225 0
# e 229 203 252 224 0
# r 254 203 273 225 0
# y 276 193 317 225 0
# g 329 195 338 237 0
# i 329 195 351 225 0
# r 353 203 364 237 0
# l 366 203 383 225 0
# ' 384 203 403 236 0
# s 407 202 424 225 0
# f 53 149 71 185 0
# a 71 149 91 171 0
# v 90 149 114 171 0
# o 116 149 138 171 0
# r 131 149 149 185 0
# i 142 149 172 183 0
# t 173 149 186 177 0
# e 189 149 208 171 0
# s 223 149 239 171 0
# o 243 149 265 171 0
# n 268 149 293 171 0
# g 295 141 317 171 0
# i 331 149 342 183 0
# s 345 149 362 171 0
# a 377 149 398 171 0
# n 398 149 424 171 0
# u 53 95 79 117 0
# n 70 95 92 128 0
# t 80 95 118 123 0
# o 112 95 130 128 0
# l 121 95 143 117 0
# d 146 95 182 128 0
# s 197 95 213 117 0
# t 215 95 228 123 0
# o 231 95 253 117 0
# r 256 95 273 117 0
# y 265 85 283 123 0
# . 271 85 304 117 0

# %%
print(type(img2box))
# Out:
# <class 'str'>

# %%
imgsH, imgsW,_ = imgs.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 imgsH, imgsW,_ = imgs.shape
#
# NameError: name 'imgs' is not defined

# %%
imgs.shape
# Out:
# (379, 500, 3)

# %%
for boxes in img2box.splitlines():
    boxes = boxes.split(' ')
    x,y,w,h = int(boxes[1]), int(boxes[2]), int(boxes[3]), int(boxes[4])
    cv2.rectangle(imgs, (x, imgsH-y), (w, imgsH-h), (0,0,225), 3)

# %%
plt.imshow(imgs)

# %%
plt.imshow(cv2.cvtColor(imgs, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Reading text using webcam

# %%
font_scale = 1.5
font_style = cv2.FONT_HERSHEY_PLAIN

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Something wrong")
    
cntr = 0

while True:
    ret,frame = cap.read()
    cntr = cntr + 1
    if cntr % 20 == 0:
        imgH, imgW,_ = frame.shape
        
        x1,y1, w1,h1 = 0,0,imgH, imgW
        imgChar = pytesseract.image_to_string(frame)
        imgBox = pytesseract.image_to_boxes(frame)
        
        for boxes in imgBox.splitlines():
            boxes = boxes.split(' ')
            x,y,w,h = int(boxes[1]), int(boxes[2]), int(boxes[3]), int(boxes[4])
            cv2.rectangle(frame, (x, imgH-y), (w, imgH-h), (0,0,225), 1) 
        
        cv2.putText(frame, imgChar, (x1 + int(h1/50), y1 +int(h1/50)), cv2.FONT_HERSHEY_SIMPLEX, 0.7,(255,255,0),2 )
        font = cv2.FONT_HERSHEY_SIMPLEX
        
        cv2.imshow("Text Detection", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
